# %%
colors = ['rouge', 'vert', 'bleu', 'jaune', 'rose', 'noir']
positions = ['ADDP', 'EDDP', 'SDP', 'ADDS', 'EDDS', 'SDS']

# Saisie de l'ordre de la matrice

while True:
    order = int(input("Entrez l'ordre de la matrice carrée (supérieur à 4) : "))
    if order > 4 :  
      break
    print("L'ordre de la matrice doit etre superieur")


matrix = []
row = []
while True:
            position = input("Entrez la position  ")
            if position in positions:
                 break
            print("Position invalide.")
while True:
             color = input("Entrez la couleur ")
             if color in colors:
                 colors.remove(color)
                 break
             print("Couleur invalide.")
row.append((position, color))
matrix.append(row)


matrice=[]
tmp=''
liste=[]
for i in range (order):
        for j in range (order):
            if position=='EDDS' :
                if i + j > order -1:
                
                    if color=="rouge" :
                        tmp="\033[0;31mo\033[00m"
                    elif color=="bleu " :
                        tmp="\033[48;5mo\033[0m"
                    elif color=="vert" :
                        tmp="\033[0;32mo\033[00m"
                    elif color=="jaune" :
                        tmp="\033[0;33mo\033[00m"
                    elif color=="rose" :
                        tmp= "\033[0;35mo\033[00m"
                    elif color=="noir" :  
                        tmp="\033[0;30mo\033[00m"        
                else :
                
                    tmp="o"
            if position=='SDP' :
                if i == j :
                
                    if color=="rouge" :
                        tmp="\033[0;31mo\033[00m"
                    elif color=="bleu " :
                        tmp="\033[48;5mo\033[0m"
                    elif color=="vert" :
                        tmp="\033[0;32mo\033[00m"
                    elif color=="jaune" :
                        tmp="\033[0;33mo\033[00m"
                    elif color=="rose" :
                        tmp= "\033[0;35mo\033[00m"
                    elif color=="noir" :  
                        tmp="\033[0;30mo\033[00m"        
                else :
                
                    tmp="o"   
            if position == 'SDS' :
                if i + j == order - 1:
                
                    if color=="rouge" :
                        tmp="\033[0;31mo\033[00m"
                    elif color=="bleu" :
                        tmp="\033[34mo\033[0m"
                    elif color=="vert" :
                        tmp="\033[0;32mo\033[00m"
                    elif color=="jaune" :
                        tmp="\033[0;33mo\033[00m"
                    elif color=="rose" :
                        tmp= "\033[0;35mo\033[00m"
                    elif color=="noir" :  
                        tmp="\033[0;30mo\033[00m"        
                else :
                
                    tmp="o"      
            if position == 'ADDP' :
                if i < j:
                
                    if color=="rouge" :
                        tmp="\033[0;31mo\033[00m"
                    elif color=="bleu " :
                        tmp="\033[48;5mo\033[0m"
                    elif color=="vert" :
                        tmp="\033[0;32mo\033[00m"
                    elif color=="jaune" :
                        tmp="\033[0;33mo\033[00m"
                    elif color=="rose" :
                        tmp= "\033[0;35mo\033[00m"
                    elif color=="noir" :  
                        tmp="\033[0;30mo\033[00m"        
                else :
                
                    tmp="o" 
            if position == 'EDDP'  :
                if i > j:
                
                    if color=="rouge" :
                        tmp="\033[0;31mo\033[00m"
                    elif color=="bleu " :
                        tmp="\033[48;5mo\033[0m"
                    elif color=="vert" :
                        tmp="\033[0;32mo\033[00m"
                    elif color=="jaune" :
                        tmp="\033[0;33mo\033[00m"
                    elif color=="rose" :
                        tmp= "\033[0;35mo\033[00m"
                    elif color=="noir" :  
                        tmp="\033[0;30mo\033[00m"        
                else :
                
                    tmp="o" 

            if position == 'ADDS'   :
                if  i + j < order - 1 :
                
                    if color=="rouge" :
                        tmp="\033[0;31mo\033[00m"
                    elif color=="bleu " :
                        tmp="\033[48;5mo\033[0m"
                    elif color=="vert" :
                        tmp="\033[0;32mo\033[00m"
                    elif color=="jaune" :
                        tmp="\033[0;33mo\033[00m"
                    elif color=="rose" :
                        tmp= "\033[0;35mo\033[00m"
                    elif color=="noir" :  
                        tmp="\033[0;30mo\033[00m"        
                else :
                
                    tmp="o"                                      

            
            liste.append(tmp)
        matrice.append(liste)
        liste=[]
for liste in matrice:
        for valeur in liste:
            print(valeur, end='  ')
        print()
# Out:
# o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o
